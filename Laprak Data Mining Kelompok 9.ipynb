# %% [markdown]
# ## Library

# %%
#import library
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Input Data

# %%
df_bb = pd.read_excel('Indo_8_1659080935.xlsx', sheet_name = 'Berat Bersih')
df_bb
# Out:
#      Negara Tujuan    2000    2001    2002    2003    2004    2005    2006  \
# 0           Jepang  2162.6  1622.5  1662.8    2339  2803.9  3303.7  3476.8
# 1    Korea Selatan   330.7   207.6  1900.5  1133.4   962.2   482.4   640.7
# 2       Tiongkok1)  1625.3  1298.7   276.8   742.4   598.9   404.4   498.7
# 3         Thailand       -       -     7.3    34.3   109.5     5.2   120.3
# 4        Singapura  2481.2  1987.7  1635.1  1253.1  1021.8  1105.9  1711.4
# 5         Malaysia       -       -    55.4    45.4   130.4   105.8   114.3
# 6            India       -       -   647.2   579.7   298.2   134.8   221.3
# 7        Australia   354.5   380.6       -       -       -       -       -
# 8  Amerika Serikat     200   189.9   110.1   422.6   307.2   181.4    88.1
# 9          Lainnya  1632.3  1320.8  1278.8   875.1   568.3   270.4   175.3
#
#      2007    2008  ...    2012    2013    2014    2015    2016    2017  \
# ...

# %%
df_fob = pd.read_excel('Indo_8_1659080935.xlsx', sheet_name = 'FOB')
df_fob
# Out:
#      Negara Tujuan   2000   2001   2002   2003   2004    2005    2006    2007  \
# 0           Jepang  419.1  284.9  290.1  487.8  692.7  1074.8  1289.1  1415.4
# 1    Korea Selatan   56.2   28.1  295.6  218.4  222.6   128.9   234.3   208.5
# 2       Tiongkok1)  322.6  225.8   67.5  148.6  131.9   143.2     238   157.4
# 3         Thailand      -      -    2.6   14.3     46     3.1    73.9    35.5
# 4        Singapura  433.2  309.2  310.9  295.4  275.2   402.6   767.3   821.9
# 5         Malaysia      -      -   14.4   11.9   25.5    32.2    48.3   111.9
# 6            India      -      -  107.3  114.2   55.3    12.9    62.5    58.9
# 7        Australia   79.4   87.7      -      -      -       -       -       -
# 8  Amerika Serikat   35.4   28.5   15.3   76.4   64.6    53.1    29.8     0.1
# 9          Lainnya  305.7  225.2  203.8  186.7  140.6    81.2   100.4    69.2
#
#      2008  ...    2012    2013    2014   2015   2016   2017   2018   2019  \
# ...

# %% [markdown]
# ## 1. Data Preprocessing I

# %%
df_bb.loc[2, 'Negara Tujuan'] = 'Tiongkok'

# %%
df_fob.loc[2, 'Negara Tujuan'] = 'Tiongkok'

# %%
df_bb.set_index('Negara Tujuan', inplace=True)

# %%
df_fob.set_index('Negara Tujuan', inplace=True)

# %%
df_bb
# Out:
#                    2000    2001    2002    2003    2004    2005    2006  \
# Negara Tujuan
# Jepang           2162.6  1622.5  1662.8    2339  2803.9  3303.7  3476.8
# Korea Selatan     330.7   207.6  1900.5  1133.4   962.2   482.4   640.7
# Tiongkok         1625.3  1298.7   276.8   742.4   598.9   404.4   498.7
# Thailand              -       -     7.3    34.3   109.5     5.2   120.3
# Singapura        2481.2  1987.7  1635.1  1253.1  1021.8  1105.9  1711.4
# Malaysia              -       -    55.4    45.4   130.4   105.8   114.3
# India                 -       -   647.2   579.7   298.2   134.8   221.3
# Australia         354.5   380.6       -       -       -       -       -
# Amerika Serikat     200   189.9   110.1   422.6   307.2   181.4    88.1
# Lainnya          1632.3  1320.8  1278.8   875.1   568.3   270.4   175.3
#
#                    2007    2008    2009  ...    2012    2013    2014    2015  \
# Negara Tujuan                            ...
# ...

# %%
df_fob
# Out:
#                   2000   2001   2002   2003   2004    2005    2006    2007  \
# Negara Tujuan
# Jepang           419.1  284.9  290.1  487.8  692.7  1074.8  1289.1  1415.4
# Korea Selatan     56.2   28.1  295.6  218.4  222.6   128.9   234.3   208.5
# Tiongkok         322.6  225.8   67.5  148.6  131.9   143.2     238   157.4
# Thailand             -      -    2.6   14.3     46     3.1    73.9    35.5
# Singapura        433.2  309.2  310.9  295.4  275.2   402.6   767.3   821.9
# Malaysia             -      -   14.4   11.9   25.5    32.2    48.3   111.9
# India                -      -  107.3  114.2   55.3    12.9    62.5    58.9
# Australia         79.4   87.7      -      -      -       -       -       -
# Amerika Serikat   35.4   28.5   15.3   76.4   64.6    53.1    29.8     0.1
# Lainnya          305.7  225.2  203.8  186.7  140.6    81.2   100.4    69.2
#
#                    2008   2009  ...    2012    2013    2014   2015   2016  \
# Negara Tujuan                   ...
# ...

# %%
df_bb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, Jepang to Lainnya
# Data columns (total 22 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2000    10 non-null     object
#  1   2001    10 non-null     object
#  2   2002    10 non-null     object
#  3   2003    10 non-null     object
#  4   2004    10 non-null     object
#  5   2005    10 non-null     object
#  6   2006    10 non-null     object
#  7   2007    10 non-null     object
#  8   2008    10 non-null     object
#  9   2009    10 non-null     object
#  10  2010    10 non-null     object
#  11  2011    10 non-null     object
#  12  2012    10 non-null     float64
#  13  2013    10 non-null     float64
#  14  2014    10 non-null     float64
#  15  2015    10 non-null     float64
#  16  2016    10 non-null     float64
#  17  2017    10 non-null     float64
#  18  2018    10 non-null     float64
#  19  2019    10 non-null     float64
#  20  2020    10 non-null     float64
# ...

# %%
df_fob.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, Jepang to Lainnya
# Data columns (total 22 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2000    10 non-null     object
#  1   2001    10 non-null     object
#  2   2002    10 non-null     object
#  3   2003    10 non-null     object
#  4   2004    10 non-null     object
#  5   2005    10 non-null     object
#  6   2006    10 non-null     object
#  7   2007    10 non-null     object
#  8   2008    10 non-null     object
#  9   2009    10 non-null     object
#  10  2010    10 non-null     object
#  11  2011    10 non-null     object
#  12  2012    10 non-null     float64
#  13  2013    10 non-null     float64
#  14  2014    10 non-null     float64
#  15  2015    10 non-null     float64
#  16  2016    10 non-null     float64
#  17  2017    10 non-null     float64
#  18  2018    10 non-null     float64
#  19  2019    10 non-null     float64
#  20  2020    10 non-null     float64
# ...

# %%
df_bb.loc['Thailand', 2000]
# Out:
# '-'

# %%
df_bb.replace(to_replace='-', value=np.NaN, inplace=True)

# %%
df_fob.replace(to_replace='-', value=np.NaN, inplace=True)

# %%
df_bb
# Out:
#                    2000    2001    2002    2003    2004    2005    2006  \
# Negara Tujuan
# Jepang           2162.6  1622.5  1662.8  2339.0  2803.9  3303.7  3476.8
# Korea Selatan     330.7   207.6  1900.5  1133.4   962.2   482.4   640.7
# Tiongkok         1625.3  1298.7   276.8   742.4   598.9   404.4   498.7
# Thailand            NaN     NaN     7.3    34.3   109.5     5.2   120.3
# Singapura        2481.2  1987.7  1635.1  1253.1  1021.8  1105.9  1711.4
# Malaysia            NaN     NaN    55.4    45.4   130.4   105.8   114.3
# India               NaN     NaN   647.2   579.7   298.2   134.8   221.3
# Australia         354.5   380.6     NaN     NaN     NaN     NaN     NaN
# Amerika Serikat   200.0   189.9   110.1   422.6   307.2   181.4    88.1
# Lainnya          1632.3  1320.8  1278.8   875.1   568.3   270.4   175.3
#
#                    2007    2008    2009  ...    2012    2013    2014    2015  \
# Negara Tujuan                            ...
# ...

# %%
df_fob
# Out:
#                   2000   2001   2002   2003   2004    2005    2006    2007  \
# Negara Tujuan
# Jepang           419.1  284.9  290.1  487.8  692.7  1074.8  1289.1  1415.4
# Korea Selatan     56.2   28.1  295.6  218.4  222.6   128.9   234.3   208.5
# Tiongkok         322.6  225.8   67.5  148.6  131.9   143.2   238.0   157.4
# Thailand           NaN    NaN    2.6   14.3   46.0     3.1    73.9    35.5
# Singapura        433.2  309.2  310.9  295.4  275.2   402.6   767.3   821.9
# Malaysia           NaN    NaN   14.4   11.9   25.5    32.2    48.3   111.9
# India              NaN    NaN  107.3  114.2   55.3    12.9    62.5    58.9
# Australia         79.4   87.7    NaN    NaN    NaN     NaN     NaN     NaN
# Amerika Serikat   35.4   28.5   15.3   76.4   64.6    53.1    29.8     0.1
# Lainnya          305.7  225.2  203.8  186.7  140.6    81.2   100.4    69.2
#
#                    2008   2009  ...    2012    2013    2014   2015   2016  \
# Negara Tujuan                   ...
# ...

# %% [markdown]
# ## 2. Data preprocessing II

# %% [markdown]
# ### missing value

# %%
df_fob.isna().sum()
# Out:
# 2000    3
# 2001    3
# 2002    1
# 2003    1
# 2004    1
# 2005    1
# 2006    1
# 2007    1
# 2008    1
# 2009    1
# 2010    1
# 2011    1
# 2012    0
# 2013    0
# 2014    0
# 2015    0
# 2016    0
# 2017    0
# 2018    0
# 2019    0
# 2020    0
# 2021    0
# dtype: int64

# %%
df_bb.isna().sum()
# Out:
# 2000    3
# 2001    3
# 2002    1
# 2003    1
# 2004    1
# 2005    1
# 2006    1
# 2007    1
# 2008    1
# 2009    1
# 2010    1
# 2011    1
# 2012    0
# 2013    0
# 2014    0
# 2015    0
# 2016    0
# 2017    0
# 2018    0
# 2019    0
# 2020    0
# 2021    0
# dtype: int64

# %%
df_bb.T.fillna(value=df_bb.T.mean(), inplace=True)
df_fob.T.fillna(value=df_fob.T.mean(), inplace=True)

# %%
df_bb.isna().sum()
# Out:
# 2000    0
# 2001    0
# 2002    0
# 2003    0
# 2004    0
# 2005    0
# 2006    0
# 2007    0
# 2008    0
# 2009    0
# 2010    0
# 2011    0
# 2012    0
# 2013    0
# 2014    0
# 2015    0
# 2016    0
# 2017    0
# 2018    0
# 2019    0
# 2020    0
# 2021    0
# dtype: int64

# %%
df_fob.isna().sum()
# Out:
# 2000    0
# 2001    0
# 2002    0
# 2003    0
# 2004    0
# 2005    0
# 2006    0
# 2007    0
# 2008    0
# 2009    0
# 2010    0
# 2011    0
# 2012    0
# 2013    0
# 2014    0
# 2015    0
# 2016    0
# 2017    0
# 2018    0
# 2019    0
# 2020    0
# 2021    0
# dtype: int64

# %% [markdown]
# ### EDA

# %%
plt.figure(figsize=(10, 7))
sns.boxplot(df_bb.T)
# Out:
# <Axes: xlabel='Negara Tujuan'>

# %%
plt.figure(figsize=(10, 7))
sns.boxplot(df_fob.T)
# Out:
# <Axes: xlabel='Negara Tujuan'>

# %% [markdown]
# ### Agregration

# %%
df_fob
# Out:
#                     2000     2001        2002        2003        2004  \
# Negara Tujuan
# Jepang           419.100  284.900  290.100000  487.800000  692.700000
# Korea Selatan     56.200   28.100  295.600000  218.400000  222.600000
# Tiongkok         322.600  225.800   67.500000  148.600000  131.900000
# Thailand          14.205   14.205    2.600000   14.300000   46.000000
# Singapura        433.200  309.200  310.900000  295.400000  275.200000
# Malaysia         750.990  750.990   14.400000   11.900000   25.500000
# India             54.430   54.430  107.300000  114.200000   55.300000
# Australia         79.400   87.700   30.791667   30.791667   30.791667
# Amerika Serikat   35.400   28.500   15.300000   76.400000   64.600000
# Lainnya          305.700  225.200  203.800000  186.700000  140.600000
#
#                         2005         2006         2007         2008  \
# Negara Tujuan
# Jepang           1074.800000  1289.100000  1415.400000  1819.900000
# ...

# %%
df_fob.T
# Out:
# Negara Tujuan  Jepang  Korea Selatan  Tiongkok  Thailand  Singapura  Malaysia  \
# 2000            419.1           56.2     322.6    14.205      433.2    750.99
# 2001            284.9           28.1     225.8    14.205      309.2    750.99
# 2002            290.1          295.6      67.5     2.600      310.9     14.40
# 2003            487.8          218.4     148.6    14.300      295.4     11.90
# 2004            692.7          222.6     131.9    46.000      275.2     25.50
# 2005           1074.8          128.9     143.2     3.100      402.6     32.20
# 2006           1289.1          234.3     238.0    73.900      767.3     48.30
# 2007           1415.4          208.5     157.4    35.500      821.9    111.90
# 2008           1819.9          238.7     191.5    24.100      990.1    124.90
# 2009            540.4          306.1     255.5     5.900      512.2    516.00
# 2010            839.3          393.8     566.5     1.400      922.7    880.00
# ...

# %%
df_bb
# Out:
#                      2000      2001         2002         2003         2004  \
# Negara Tujuan
# Jepang           2162.600  1622.500  1662.800000  2339.000000  2803.900000
# Korea Selatan     330.700   207.600  1900.500000  1133.400000   962.200000
# Tiongkok         1625.300  1298.700   276.800000   742.400000   598.900000
# Thailand           21.510    21.510     7.300000    34.300000   109.500000
# Singapura        2481.200  1987.700  1635.100000  1253.100000  1021.800000
# Malaysia         1505.575  1505.575    55.400000    45.400000   130.400000
# India             231.800   231.800   647.200000   579.700000   298.200000
# Australia         354.500   380.600    87.616667    87.616667    87.616667
# Amerika Serikat   200.000   189.900   110.100000   422.600000   307.200000
# Lainnya          1632.300  1320.800  1278.800000   875.100000   568.300000
#
#                         2005         2006         2007         2008  \
# Negara Tujuan
# ...

# %%
df_bb.T
# Out:
# Negara Tujuan  Jepang  Korea Selatan  Tiongkok  Thailand  Singapura  Malaysia  \
# 2000           2162.6          330.7    1625.3     21.51     2481.2  1505.575
# 2001           1622.5          207.6    1298.7     21.51     1987.7  1505.575
# 2002           1662.8         1900.5     276.8      7.30     1635.1    55.400
# 2003           2339.0         1133.4     742.4     34.30     1253.1    45.400
# 2004           2803.9          962.2     598.9    109.50     1021.8   130.400
# 2005           3303.7          482.4     404.4      5.20     1105.9   105.800
# 2006           3476.8          640.7     498.7    120.30     1711.4   114.300
# 2007           3226.2          477.1     402.3     53.00     1553.4   260.800
# 2008           2856.4          403.9     387.8     26.60     1434.5   195.700
# 2009           1451.9          654.8     659.7     11.50     1087.7  1276.800
# 2010           1668.1          639.9    1209.6      1.30     1431.1  1753.800
# ...

# %%
data_dict = {
    'Netto': df_bb.T.sum(),
    'FOB': df_fob.T.sum()
}
df = pd.DataFrame(data_dict, index=df_fob.index)
df
# Out:
#                         Netto           FOB
# Negara Tujuan
# Jepang           30146.800000  11636.800000
# Korea Selatan    10828.600000   4658.200000
# Tiongkok         12157.000000   4642.500000
# Thailand           473.220000    312.510000
# Singapura        25165.400000  10545.800000
# Malaysia         33122.650000  16521.780000
# India             5099.600000   1197.460000
# Australia         1927.566667    677.416667
# Amerika Serikat   1935.400000    665.100000
# Lainnya           9940.700000   3906.600000

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %% [markdown]
# ## 3. Modeling

# %% [markdown]
# ### Elbow

# %%
from sklearn.cluster import KMeans

# %%
inertia = []

for i in range(2, 11):
    kmeans = KMeans(n_clusters=i, random_state=0)
    kmeans.fit(df)
    inertia.append(kmeans.inertia_)



plt.figure(figsize=(20, 10))

sns.lineplot(x=range(2, 11), y=inertia, color='#000087', linewidth = 4)
sns.scatterplot(x=range(2, 11), y=inertia, s=300, color='#800000',  linestyle='--')
plt.figure()

# %% [markdown]
# ### K-means

# %%
kmeans = KMeans(n_clusters=3, random_state=42)

# Fit the K-Means model to the data
kmeans.fit(df)

# Obtain the cluster labels for each data point
labels_kmeans = kmeans.labels_

centroids_kmeans = kmeans.cluster_centers_

# %%
labels_kmeans
# Out:
# array([1, 2, 2, 0, 1, 1, 0, 0, 0, 2], dtype=int32)

# %%
centroids_kmeans
# Out:
# array([[ 2358.94666667,   713.12166667],
#        [29478.28333333, 12901.46      ],
#        [10975.43333333,  4402.43333333]])

# %%
df['cluster_by_kmeans'] = labels_kmeans

# %%
df
# Out:
#                         Netto           FOB  cluster_by_kmeans
# Negara Tujuan
# Jepang           30146.800000  11636.800000                  1
# Korea Selatan    10828.600000   4658.200000                  2
# Tiongkok         12157.000000   4642.500000                  2
# Thailand           473.220000    312.510000                  0
# Singapura        25165.400000  10545.800000                  1
# Malaysia         33122.650000  16521.780000                  1
# India             5099.600000   1197.460000                  0
# Australia         1927.566667    677.416667                  0
# Amerika Serikat   1935.400000    665.100000                  0
# Lainnya           9940.700000   3906.600000                  2

# %%
df[df.columns].groupby('cluster_by_kmeans').agg(['mean','median'])
# Out:
#                           Netto                         FOB
#                            mean        median          mean        median
# cluster_by_kmeans
# 0                   2358.946667   1931.483333    713.121667    671.258333
# 1                  29478.283333  30146.800000  12901.460000  11636.800000
# 2                  10975.433333  10828.600000   4402.433333   4642.500000

# %% [markdown]
# ### Visualization for kmeans clustering

# %%
fig, ax = plt.subplots(figsize=(15,10))

sns.scatterplot(
    x=df['Netto'], 
    y=df["FOB"],
    hue=df['cluster_by_kmeans'],
    linestyle='--',
    s=160,
    ax=ax
)

plt.show()

# %% [markdown]
# ### K-medoids

# %%
# !pip install scikit-learn-extra
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 34.0 MB/s eta 0:00:00
# ...

# %%
from sklearn_extra.cluster import KMedoids

# %%
km = KMedoids(n_clusters=3, random_state=24)
km.fit(df)

labels_kmedoid = km.labels_

# %%
labels_kmedoid
# Out:
# array([2, 1, 1, 0, 2, 2, 0, 0, 0, 1])

# %%
df['cluster_by_kmedoids'] = labels_kmedoid

# %%
df
# Out:
#                         Netto           FOB  cluster_by_kmeans  \
# Negara Tujuan
# Jepang           30146.800000  11636.800000                  1
# Korea Selatan    10828.600000   4658.200000                  2
# Tiongkok         12157.000000   4642.500000                  2
# Thailand           473.220000    312.510000                  0
# Singapura        25165.400000  10545.800000                  1
# Malaysia         33122.650000  16521.780000                  1
# India             5099.600000   1197.460000                  0
# Australia         1927.566667    677.416667                  0
# Amerika Serikat   1935.400000    665.100000                  0
# Lainnya           9940.700000   3906.600000                  2
#
#                  cluster_by_kmedoids
# Negara Tujuan
# Jepang                             2
# Korea Selatan                      1
# Tiongkok                           1
# Thailand                           0
# Singapura                          2
# ...

# %%
df[['Netto', 'FOB']].groupby(df['cluster_by_kmedoids']).agg(['mean','median'])
# Out:
#                             Netto                         FOB
#                              mean        median          mean        median
# cluster_by_kmedoids
# 0                     2358.946667   1931.483333    713.121667    671.258333
# 1                    10975.433333  10828.600000   4402.433333   4642.500000
# 2                    29478.283333  30146.800000  12901.460000  11636.800000

# %% [markdown]
# ### Visualization for clustering by k-medoids

# %%
fig, ax = plt.subplots(figsize=(15,10))

sns.scatterplot(
    x=df['Netto'], 
    y=df["FOB"],
    hue = df['cluster_by_kmedoids'],
    linestyle='--',
    s=160,
    ax=ax
)

plt.show()
